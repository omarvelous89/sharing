# %%
import math
import warnings

from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn import linear_model
from sklearn.cross_decomposition import PLSRegression

# %matplotlib inline
sns.set_style('white')

# Suppress annoying harmless error.
warnings.filterwarnings(
    action="ignore",
    module="scipy",
    message="^internal gelsd"
)

# %%
# Number of datapoints in outcome.
n = 1000

# Number of features.
p = 7

# Create random normally distributed data for parameters.
X = np.random.gamma(shape=9, size=(n,p))

# outcome variable with multiplication
y = X[:, 0] + 2 * X[:, 1] + np.random.normal(size=n * 1) + 5



# Check out correlations. First column is the outcome.
f, ax = plt.subplots(figsize=(12, 9))
corrmat = pd.DataFrame(np.insert(X, 0, y, axis=1)).corr()

# Draw the heatmap using seaborn.
sns.heatmap(corrmat, vmax=.8, square=True)
plt.show()

# %%
# Fit a linear model with all 10 features.
regr = linear_model.LinearRegression()
regr.fit(X, y)

# Save predicted values.
Y_pred = regr.predict(X)
print('R-squared regression:', regr.score(X, y))

# Fit a linear model using Partial Least Squares Regression.
# Reduce feature space to 3 dimensions.
pls1 = PLSRegression(n_components=3)

# Reduce X to R(X) and regress on y.
pls1.fit(X, y)

# Save predicted values.
Y_PLS_pred = pls1.predict(X)
print('R-squared PLSR:', pls1.score(X, y))

# Compare the predictions of the two models
plt.scatter(Y_pred,Y_PLS_pred) 
plt.xlabel('Predicted by original 10 features')
plt.ylabel('Predicted by 3 features')
plt.title('Comparing LR and PLSR predictions')
plt.show()
# Out:
# R-squared regression: 0.9772372344692059
# R-squared PLSR: 0.977237161740419

# %%
# outcome variable with division
y1 = X[:, 0] + 2 / X[:, 1] + np.random.normal(size=n * 1) + 5

# Check out correlations. First column is the outcome.
f, ax = plt.subplots(figsize=(12, 9))
corrmat1 = pd.DataFrame(np.insert(X, 0, y1, axis=1)).corr()

sns.heatmap(corrmat1, vmax=.8, square=True)
plt.show()

# %%
# Fit a linear model with all 10 features.
regr1 = linear_model.LinearRegression()
regr1.fit(X, y1)

# Save predicted values.
Y_pred1 = regr1.predict(X)
print('R-squared regression:', regr.score(X, y1))

# Fit a linear model using Partial Least Squares Regression.
# Reduce feature space to 3 dimensions.
pls1 = PLSRegression(n_components=3)

# Reduce X to R(X) and regress on y.
pls1.fit(X, y1)

# Save predicted values.
Y_PLS_pred1 = pls1.predict(X)
print('R-squared PLSR:', pls1.score(X, y1))

# Compare the predictions of the two models
plt.scatter(Y_pred1,Y_PLS_pred1) 
plt.xlabel('Predicted by original 10 features')
plt.ylabel('Predicted by 3 features')
plt.title('Comparing LR and PLSR predictions')
plt.show()
# Out:
# R-squared regression: -34.19837879178888
# R-squared PLSR: 0.9041931643683916

# %%
# outcome variable with division
y2 = (X[:, 0] + X[:, -1] ) * np.random.normal(size=n * 1) + 0.1

# Check out correlations. First column is the outcome.
f, ax = plt.subplots(figsize=(12, 9))
corrmat2 = pd.DataFrame(np.insert(X, 0, y2, axis=1)).corr()

sns.heatmap(corrmat2, vmax=.8, square=True)
plt.show()

# %%
# Fit a linear model with all 10 features.
regr2 = linear_model.LinearRegression()
regr2.fit(X, y2)

# Save predicted values.
Y_pred2 = regr2.predict(X)
print('R-squared regression:', regr2.score(X, y2))

# Fit a linear model using Partial Least Squares Regression.
# Reduce feature space to 3 dimensions.
pls1 = PLSRegression(n_components=3)

# Reduce X to R(X) and regress on y.
pls1.fit(X, y2)

# Save predicted values.
Y_PLS_pred2 = pls1.predict(X)
print('R-squared PLSR:', pls1.score(X, y2))

# Compare the predictions of the two models
plt.scatter(Y_pred2,Y_PLS_pred2) 
plt.xlabel('Predicted by original 10 features')
plt.ylabel('Predicted by 3 features')
plt.title('Comparing LR and PLSR predictions')
plt.show()
# Out:
# R-squared regression: 0.009806456734452573
# R-squared PLSR: 0.009806455671679482

# %%
# outcome variable with division
y3 = (X[:, 0] * X[:, 3] + X[:,-1]) + np.random.normal(size=n * 1) 

# Check out correlations. First column is the outcome.
f, ax = plt.subplots(figsize=(12, 9))
corrmat3 = pd.DataFrame(np.insert(X, 0, y3, axis=1)).corr()

sns.heatmap(corrmat3, vmax=.8, square=True)
plt.show()

# %%
# Fit a linear model with all 10 features.
regr3 = linear_model.LinearRegression()
regr3.fit(X, y3)

# Save predicted values.
Y_pred3 = regr3.predict(X)
print('R-squared regression:', regr3.score(X, y2))

# Fit a linear model using Partial Least Squares Regression.
# Reduce feature space to 3 dimensions.
pls1 = PLSRegression(n_components=3)

# Reduce X to R(X) and regress on y.
pls1.fit(X, y3)

# Save predicted values.
Y_PLS_pred3 = pls1.predict(X)
print('R-squared PLSR:', pls1.score(X, y3))

# Compare the predictions of the two models
plt.scatter(Y_pred3,Y_PLS_pred3) 
plt.xlabel('Predicted by original 10 features')
plt.ylabel('Predicted by 3 features')
plt.title('Comparing LR and PLSR predictions')
plt.show()
# Out:
# R-squared regression: -26.866589449479083
# R-squared PLSR: 0.9560563868732456
