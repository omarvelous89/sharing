# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

df = pd.read_csv('honeyproduction.csv')
dfCA = df.loc[lambda df: df['state'] == 'CA', :]
dfND = df.loc[lambda df: df['state'] == 'ND', :]
dfSD = df.loc[lambda df: df['state'] == 'SD', :]

plt.figure(figsize=(10,7))
plt.boxplot(df['priceperlb'])
plt.title('Price pr lb of Honey across the U.S. 1998-2012')
plt.ylabel('price per lb of Honey ($)')

dfHighPrice= df.loc[lambda df: df['priceperlb'] > 2.7]
dfHighPrice
#After noticing the large amount of outliers I produced a dataframe to see what these states possibly have in common
# Out:
#     state   numcol  yieldpercol  totalprod    stocks  priceperlb  prodvalue  \
# 324    NV  12000.0           46   552000.0  442000.0        3.11  1717000.0
# 365    NV   9000.0           37   333000.0   50000.0        3.62  1205000.0
# 406    NV  10000.0           28   280000.0   67000.0        2.99   837000.0
# 479    KY   5000.0           35   175000.0   25000.0        2.71   474000.0
# 493    OH  11000.0           50   550000.0  132000.0        2.81  1546000.0
# 501    VA   6000.0           39   234000.0   56000.0        3.45   807000.0
# 513    HI  10000.0           77   770000.0  239000.0        2.75  2118000.0
# 515    IL   9000.0           41   369000.0   92000.0        2.78  1026000.0
# 519    KY   5000.0           67   335000.0   67000.0        2.72   911000.0
# 540    VT   4000.0           65   260000.0   73000.0        3.10   806000.0
# 541    VA   5000.0           37   185000.0   37000.0        3.32   614000.0
# ...
